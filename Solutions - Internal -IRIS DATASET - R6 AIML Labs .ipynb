# %% [markdown]
# # The Iris Dataset
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# The dataset contains a set of 150 records under five attributes - petal length, petal width, sepal length, sepal width and species.

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Import dataset
# - Import iris dataset
# - Import the dataset using sklearn library

# %%
import warnings # In order to ignore FutureWarning
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
type(iris)

# %%
iris

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - you can get the features using .data method
# - you can get the features using .target method

# %%
import numpy as np

print( "Feature for IRIS DATA SET IS",iris.feature_names)
print("TARGET FOR IRIS DATA SET",iris.target_names)
print(" TARGET NAMES",iris.target_names)
np.isnan(iris.data).any()
print(iris.data[:10])

print("TARGET FOR IRIS DATA SET",iris.target)

# %%
X = iris.data 
Y = iris.target

# %%
X.shape

# %%
X.ndim
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4fdb863cdb3a> in <module>
# ----> 1 X.ndim
#
# NameError: name 'X' is not defined

# %%
Y.shape

# %%
Y.ndim

# %% [markdown]
# # Question 3

# %% [markdown]
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=7)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# %%
# Import `StandardScaler` from `sklearn.preprocessing`
from sklearn.preprocessing import StandardScaler

# Define the scaler 
scaler = StandardScaler().fit(X_train)

# Scale the train set
X_train = scaler.transform(X_train)

# Scale the test set
X_test = scaler.transform(X_test)

# %%
print(X_train.ndim, X_test.ndim, y_train.ndim, y_test.ndim)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### One-hot encode the labels
# - convert class vectors (integers) to binary class matrix
# - convert labels
# - number of classes: 3
# - we are doing this to use categorical_crossentropy as loss

# %%
#Encoding
import tensorflow as tf

def encode(labels):
    print("Shape of data (BEFORE encode): %s" % str(labels.shape))
    encoded = tf.keras.utils.to_categorical(labels, num_classes = 3, dtype = "float32")
    print("Shape of data (AFTER encode): %s" % str(encoded.shape))
    return encoded

# %%
encoded_y_train = encode(y_train)
print(encoded_y_train)

# %%
encoded_y_test = encode(y_test)
print(encoded_y_test)

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Initialize a sequential model
# - Define a sequential model

# %%
#Initialize Sequential model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential()

# %%
model

# %% [markdown]
# Question 6

# %%
#Add input layer
model.add(Dense(30, input_shape=(4,), activation='relu', name='input_layer'))
#Add 1st hidden layer
model.add(Dense(10, activation='relu', name='layer_1'))
#Add 2nd hidden layer
model.add(Dense(10, activation='relu', name='layer_2'))

# %%
model.add

# %% [markdown]
# ### Add a layer
# - Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3
# - Apply Softmax on Dense Layer outputs

# %%
#Add Output layer
model.add(Dense(3, activation='softmax', name='output_layer'))

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Compile the model
# - Use SGD as Optimizer
# - Use categorical_crossentropy as loss function
# - Use accuracy as metrics

# %%
#Compile the model
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Summarize the model
# - Check model layers
# - Understand number of trainable parameters

# %%
print('Neural Network Model Summary: ')
print(model.summary())

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Fit the model
# - Give train data as training features and labels
# - Epochs: 100
# - Give validation data as testing features and labels

# %%
model.fit(X_train,encoded_y_train, epochs=100,validation_data=(X_test,encoded_y_test))

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Make predictions
# - Predict labels on one row

# %%
y_pred = np.round(model.predict(X_test))

# %%
y_pred_1row = model.predict(X_test[0:1])

# %%
y_pred_1row_round = np.round(y_pred_1row)

# %%
print(" The Label prediction on one row is :", y_pred_1row_round)

# %%
print(" The actual label for the above row is :", encoded_y_test[0:1])

# %% [markdown]
# ### Compare the prediction with actual label
# - Print the same row as done in the previous step but of actual labels

# %%
results = model.evaluate(X_test, encoded_y_test)

print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))

# %%
print(" The actual label for the above row is :", encoded_y_test[0:1])

# %% [markdown]
# ---

# %% [markdown]
# # Stock prices dataset
# The data is of tock exchange's stock listings for each trading day of 2010 to 2016.
#
# ## Description
# A brief description of columns.
# - open: The opening market price of the equity symbol on the date
# - high: The highest market price of the equity symbol on the date
# - low: The lowest recorded market price of the equity symbol on the date
# - close: The closing recorded price of the equity symbol on the date
# - symbol: Symbol of the listed company
# - volume: Total traded volume of the equity symbol on the date
# - date: Date of record

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Load the data
# - load the csv file and read it using pandas
# - file name is prices.csv

# %%
# run this cell to upload file if you are using google colab
from google.colab import files
files.upload()

# %%
# run this cell to upload file if you are using google colab
#from google.colab import files
#files.upload()
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import pandas as pd
import numpy as np

# %%
sp_df=pd.read_csv('prices.csv')

# %%
sp_df.head()

# %%
sp_df.shape

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Drop columnns
# - drop "date" and "symbol" column from the data

# %%
# Dropping date and symbol columns
df = sp_df.drop(['date',"symbol"], axis=1)
df.head(5)

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Take initial rows
# - Take first 1000 rows from the data
# - This step is done to make the execution faster

# %%
data=df.head(1000)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - Take "open", "close", "low", "high" columns as features
# - Take "volume" column as label
# - Normalize label column by dividing it with 1000000

# %%
data.columns
X = data.drop(['volume'], axis=1) 
y = data['volume']
y[0:10]
y_sc= y/1000000
y_sc[0:10]

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Convert data
# - Convert features and labels to numpy array
# - Convert their data type to "float32"

# %%
X_np =  X.to_numpy()
y_np =  y_sc.to_numpy()
print(X_np.dtype, y_np.dtype)

# %%
X_np = np.float32(X_np)
y_np =   np.float32(y_np)

# %%
print(X_np.dtype, y_np.dtype)

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Normalize data
# - Normalize features
# - Use tf.math.l2_normalize to normalize features
# - You can read more about it here https://www.tensorflow.org/api_docs/python/tf/math/l2_normalize

# %%
X_np.ndim
X_nrm = tf.math.l2_normalize(X_np, axis=None, epsilon=1e-12, name=None)

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Define weight and bias
# - Initialize weight and bias with tf.zeros
# - tf.zeros is an initializer that generates tensors initialized to 0
# - Specify the value for shape

# %%
#number of features
n_features = X_nrm.shape[1]
X_nrm.shape
#Initializing weight and bias to zeros (Cold Start)
W = tf.Variable(tf.zeros(shape=[4,1]))
b =  tf.Variable(tf.zeros(shape=(1)))

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Get prediction
# - Define a function to get prediction
# - Approach: prediction = (X * W) + b; here is X is features

# %%
def prediction(features, W, b):
  y_pred = tf.add(tf.matmul(features,W),b)
  return y_pred

# %% [markdown]
# ### Calculate loss
# - Calculate loss using predictions
# - Define a function to calculate loss
# - We are calculating mean squared error

# %%
def loss(y_actual,y_predicted):
  diff = y_actual - y_predicted
  sqr = tf.square(diff)
  avg = tf.reduce_mean(sqr)
  return avg

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Define a function to train the model
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
def train(x, y_actual, w, b, learning_rate=0.01):
    
    # Record mathematical operations on 'tape' to calculate loss
    with tf.GradientTape() as t:
        t.watch([w,b])
        current_prediction = prediction(x, w, b)
        current_loss = loss(y_actual, current_prediction)
    
    # Calculate Gradients for Loss with respect to Weights and Bias
    dw, db = t.gradient(current_loss,[w, b])
    
    # Update Weights and Bias
    w = w - learning_rate * dw
    b = b - learning_rate * db
    
    return w, b

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Train the model for 100 epochs
# - Observe the training loss at every iteration

# %%
for i in range(100):
  W,b = train(X_nrm,y_np,W,b)
  print('Current Training loss on iteration',i,loss(y_np,prediction(X_nrm,W,b)))

# %% [markdown]
# ### Observe values of Weight
# - Print the updated values

# %%
  print('Current Training loss on iteration',i,loss(y_np,prediction(X_nrm,W,b)))

# %% [markdown]
# ### Observe values of Bias
# - Print the updated values

# %%
print(f'Updates Bias(b) value is: \n{b.numpy()}')
